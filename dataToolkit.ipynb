# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Q1 : Creating the identical 2D Array

# %%
'''[[1, 2, 3],
    [1, 2, 3],
    [1, 2, 3]]'''
## Method 1  : Numpy tile
array1 = np.tile([1, 2, 3], (3, 1))
print('Array 1\n')
print(array1)

## Method 2 : List Multiplication
array2 = np.array([[1, 2, 3]] * 3)
print('\nArray 2\n')
print(array2)

## Method 3 : 
row = np.array([1, 2, 3])
array3 = np.ones((3, 1), dtype=int) * row
print('\nArray 3\n')
print(array3)
# Out:
# Array 1
#
# [[1 2 3]
#  [1 2 3]
#  [1 2 3]]
#
# Array 2
#
# [[1 2 3]
#  [1 2 3]
#  [1 2 3]]
#
# Array 3
#
# [[1 2 3]
#  [1 2 3]
#  [1 2 3]]

# %% [markdown]
# ### Q2

# %%
arr = np.linspace(1,10,100)
arr_2d = arr.reshape(10,10)
print('\n Array 1D\n')
print(arr.shape)
print('\n Array 2D\n')
print(arr_2d.shape)
# Out:
#  Array 1D
#
# (100,)
#
#  Array 2D
#
# (10, 10)

# %% [markdown]
# # Q3
# ### Difference Between `np.array`, `np.asarray`, and `np.asanyarray`
#
# | Function         | Description                                                                                   | Copy Behavior               |
# |------------------|-----------------------------------------------------------------------------------------------|-----------------------------|
# | `np.array()`     | Always creates a new NumPy array from the input.                                              | Makes a copy (by default).  |
# | `np.asarray()`   | Converts input to array only if it’s not already an array.                                    | Avoids copy if unnecessary. |
# | `np.asanyarray()`| Same as `np.asarray()`, but preserves subclasses (e.g., `matrix`, `masked_array`).           | Avoids copy and preserves subclass. |

# %% [markdown]
# ### Differece Between the Shallow copy and Deep Copy
#
# | Type          | Definition                                                        | Memory Sharing |
# |---------------|-------------------------------------------------------------------|----------------|
# | Shallow Copy  | Creates a new object, but references the original data inside     | Shared         |
# | Deep Copy     | Creates a new object and copies the data too                      | Independent    |

# %%
arr = np.array([1, 2, 3])
shallow = arr.view()
deep = arr.copy()

arr[0] = 100 # chaning in the original array

print("Original:", arr)
print("Shallow:", shallow)  # changes happen
print("Deep:", deep)        # changes will not here
# Out:
# Original: [100   2   3]
# Shallow: [100   2   3]
# Deep: [1 2 3]

# %% [markdown]
# ### Q4

# %%
np.random.seed(34)
arr = np.random.uniform(low=5,high=20,size=(3,3))
roundedArr = np.round(arr,2)
print('Floating Number Array\n')
print(arr)
print('\nRounded Array\n')
print(roundedArr)
# Out:
# Floating Number Array
#
# [[ 5.57842521 16.70150691  6.39055633]
#  [14.4933903   5.20836272 19.04237804]
#  [11.39861573  8.79629676  7.84947959]]
#
# Rounded Array
#
# [[ 5.58 16.7   6.39]
#  [14.49  5.21 19.04]
#  [11.4   8.8   7.85]]

# %% [markdown]
# ### Q5

# %%
np.random.seed(56)
arr = np.random.randint(1,10,size=(5,6))
even_num, odd_num = arr[arr % 2 ==0] , arr[arr % 2 !=0]
print("Original Array:\n", arr)
print("\nEven Numbers:\n", even_num)
print("\nOdd Numbers:\n", odd_num)
# Out:
# Original Array:
#  [[6 5 1 3 8 7]
#  [5 8 2 9 3 1]
#  [6 7 2 6 6 3]
#  [4 6 3 2 1 5]
#  [7 3 1 9 7 5]]
#
# Even Numbers:
#  [6 8 8 2 6 2 6 6 4 6 2]
#
# Odd Numbers:
#  [5 1 3 7 5 9 3 1 7 3 3 1 5 7 3 1 9 7 5]

# %% [markdown]
# ### Q6

# %%
np.random.seed(78)
arr = np.random.randint(1,11,(3,3,3))
print("Array\n")
print(arr)
# a) Find the indices of the maximum values along the third axis (axis=2)
max_indices = np.argmax(arr, axis=2)
print("\nIndices of max values along depth (axis=2):\n", max_indices)

# b) Perform element-wise multiplication between arr and itself 
multiplied = arr * arr
print("\nElement-wise multiplication:\n", multiplied)
# Out:
# Array
#
# [[[ 6  7  8]
#   [ 9 10  7]
#   [ 9  5  5]]
#
#  [[ 4  4  9]
#   [ 5  5  7]
#   [ 7  1  8]]
#
#  [[ 4  7  5]
#   [10  8  3]
#   [ 8  4  6]]]
#
# Indices of max values along depth (axis=2):
#  [[2 1 0]
#  [2 2 2]
#  [1 0 0]]
#
# Element-wise multiplication:
#  [[[ 36  49  64]
#   [ 81 100  49]
#   [ 81  25  25]]
#
#  [[ 16  16  81]
#   [ 25  25  49]
#   [ 49   1  64]]
#
#  [[ 16  49  25]
#   [100  64   9]
#   [ 64  16  36]]]

# %% [markdown]
# ### Q7

# %%
df = pd.read_csv('peopleData.csv')
df
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    27-01-2014
# 1    fergusonkatherine@example.net                    NaN    26-07-1931
# ...

# %%
df['Phone'].isna().sum()
# Out:
# 21

# %%
df['Phone'].unique()
# Out:
# array(['857.139.8239', nan, '(599)782-0605', '(390)417-1635x3010',
#        '8537800927', '093.655.7480x7895', '4709522945', '013.820.4758',
#        '(560)903-5068x4985', '8629884096', '+1-041-859-3844x272',
#        '801.809.9181x37308', '+1-511-127-6660x230', '903.545.8947',
#        '(416)979-0633x058', '244-054-8521x1913', '(929)366-8549x3587',
#        '(973)243-9193', '060-611-9377x90160', '601.838.8295x89942',
#        '668.063.9568x7257', '(590)187-8007x273', '972.064.3833x5347',
#        '(614)275-6966x22597', '(322)679-7824', '989.482.6130x996',
#        '975-190-7875x3293', '(291)853-7982x0123', '(984)863-5741x7054',
#        '(977)846-8023', '526-208-4712x10329', '157.425.5345',
#        '600-706-8696x839', '557-620-5663', '000-364-9407x55677',
#        '(116)776-0713x4684', '+1-932-606-8425x22206', '341.096.2708x237',
#        '+1-833-716-3269x028', '001-313-023-3603x2485',
#        '001-366-475-8607x04350', '(412)388-9715', '353.983.3416',
# ...

# %%
import re
def clean_phone(phone):
    # 1) Handle true NaNs
    if pd.isna(phone):
        return pd.NA

    # 2) Work with a stripped string
    phone_str = str(phone).strip()

    # 3) Drop anything after an 'x' or 'X' (extension)
    phone_str = re.split(r'[xX]', phone_str)[0]

    # 4) Remove all non-digits
    digits = re.sub(r'\D+', '', phone_str)

    # 5) If nothing remains, mark as NA, else convert to int
    return pd.NA if digits == '' else int(digits)

# Apply and cast to pandas nullable Int64
df['Phone'] = df['Phone'].apply(clean_phone).astype('Int64')

print(df['Phone'].dtype)  
print(df['Phone'].head())
# Out:
# Int64
# 0    8571398239
# 1          <NA>
# 2    5997820605
# 3          <NA>
# 4    3904171635
# Name: Phone, dtype: Int64

# %%
df=df[~df['Phone'].isna()]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 979 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          979 non-null    int64
#  1   User Id        979 non-null    object
#  2   First Name     979 non-null    object
#  3   Last Name      979 non-null    object
#  4   Gender         979 non-null    object
#  5   Email          979 non-null    object
#  6   Phone          979 non-null    Int64
#  7   Date of birth  979 non-null    object
#  8   Job Title      979 non-null    object
#  9   Salary         979 non-null    int64
# dtypes: Int64(1), int64(2), object(7)
# memory usage: 85.1+ KB

# %% [markdown]
# ### Q8

# %%
## a) read with skping the first 50 rows
data = pd.read_csv('peopleData.csv',skiprows=50)
data
# Out:
#        50  afF3018e9cdd1dA     George    Mercer  Female  \
# 0      51  CccE5DAb6E288e5         Jo    Zavala    Male
# 1      52  DfBDc3621D4bcec     Joshua     Carey  Female
# 2      53  f55b0A249f5E44D     Rickey     Hobbs  Female
# 3      54  Ed71DcfaBFd0beE      Robyn    Reilly    Male
# 4      55  FDaFD0c3f5387EC  Christina    Conrad    Male
# ..    ...              ...        ...       ...     ...
# 945   996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 946   997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 947   998  2adde51d8B8979E      Cathy  Mckinney  Female
# 948   999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 949  1000  8b756f6231DDC6e        Lee      Tran  Female
#
#     douglascontreras@example.net    +1-326-669-0118x4341  11-09-1941  \
# 0           pamela64@example.net  001-859-448-9935x54536  23-11-1992
# 1      dianashepherd@example.net    001-274-739-8470x814  07-01-1915
# 2      ingramtiffany@example.org        241.179.9509x498  01-07-1910
# ...

# %%
# b)
df = pd.read_csv('peopleData.csv', usecols=['Last Name', 'Gender', 'Email', 'Phone', 'Salary'])
df
# Out:
#     Last Name  Gender                          Email                  Phone  \
# 0     Mahoney    Male            pwarner@example.org           857.139.8239
# 1      Rivers  Female  fergusonkatherine@example.net                    NaN
# 2      Lowery  Female            fhoward@example.org          (599)782-0605
# 3      Hooper    Male          zjohnston@example.com                    NaN
# 4        Rice  Female               elin@example.net     (390)417-1635x3010
# ..        ...     ...                            ...                    ...
# 995    Bryant  Female         lyonsdaisy@example.net           021.775.2933
# 996     Barry  Female        dariusbryan@example.com   001-149-710-7799x721
# 997  Mckinney  Female         georgechan@example.org  +1-750-774-4128x33265
# 998    Phelps    Male            wanda04@example.net          (915)292-2254
# 999      Tran  Female        deannablack@example.org     079.752.5424x67259
#
#      Salary
# 0     90000
# 1     80000
# 2     50000
# ...

# %%
# c)
df.head(10)
# Out:
#   Last Name  Gender                          Email               Phone  Salary
# 0   Mahoney    Male            pwarner@example.org        857.139.8239   90000
# 1    Rivers  Female  fergusonkatherine@example.net                 NaN   80000
# 2    Lowery  Female            fhoward@example.org       (599)782-0605   50000
# 3    Hooper    Male          zjohnston@example.com                 NaN   65000
# 4      Rice  Female               elin@example.net  (390)417-1635x3010  100000
# 5  Caldwell    Male          kaitlin13@example.net          8537800927   50000
# 6   Hoffman    Male         jeffharvey@example.com   093.655.7480x7895   60000
# 7  Andersen    Male           alicia33@example.org          4709522945   65000
# 8      Mays    Male             jake50@example.com        013.820.4758   50000
# 9  Mitchell    Male      lanechristina@example.net  (560)903-5068x4985   50000

# %%
# d)
df['Salary'].tail(5)
# Out:
# 995     90000
# 996     50000
# 997     60000
# 998    100000
# 999     90000
# Name: Salary, dtype: int64

# %% [markdown]
# ### Q9

# %%
df=pd.read_csv('peopleData.csv')

# %%
df[(df['Last Name'] == "Duke") & (df['Gender'] == "Female") & (df['Salary'] < 85000)]
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 45      46  99A502C175C4EBd     Olivia      Duke  Female
# 210    211  DF17975CC0a0373    Katrina      Duke  Female
# 457    458  dcE1B7DE83c1076      Traci      Duke  Female
# 729    730  c9b482D7aa3e682     Lonnie      Duke  Female
#
#                         Email                   Phone Date of birth  \
# 45        diana26@example.net  001-366-475-8607x04350    13-10-1934
# 210       robin78@example.com            740.434.0212    21-09-1935
# 457  perryhoffman@example.org     +1-903-596-0995x489    11-02-1997
# 729   kevinkramer@example.net            982.692.6257    12-05-2015
#
#            Job Title  Salary
# 45           Dentist   60000
# 210  Producer, radio   50000
# 457        Herbalist   50000
# 729     Nurse, adult   70000

# %% [markdown]
# ### Q10

# %%
num = pd.Series(np.random.randint(1,7, size=35))
dataFrame = pd.DataFrame(num.values.reshape(7,5))

# %%
dataFrame
# Out:
#    0  1  2  3  4
# 0  5  6  3  2  3
# 1  5  6  2  1  1
# 2  5  1  5  5  2
# 3  1  2  5  1  2
# 4  1  2  4  3  6
# 5  1  6  2  5  5
# 6  5  5  5  4  1

# %% [markdown]
# ### Q11

# %%
seris1=pd.Series(np.random.randint(10,51, size=50))
seris2=pd.Series(np.random.randint(100,1001, size=50))
df = pd.concat([seris1,seris2],axis=1)
df.columns=['col1','col2']
df.head(10)
# Out:
#    col1  col2
# 0    18   843
# 1    26   290
# 2    44   909
# 3    27   749
# 4    32   489
# 5    34   996
# 6    20   108
# 7    29   691
# 8    39   968
# 9    33   324

# %% [markdown]
# ### Q12

# %%
df = pd.read_csv('peopleData.csv')
df = df.drop(['Email', 'Phone', 'Date of birth'], errors='ignore',axis =1)
df = df.dropna()
df.head(19)
# Out:
#     Index          User Id First Name Last Name  Gender  \
# 0       1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1       2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2       3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3       4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4       5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# 5       6  aF75e6dDEBC5b66     Sherry  Caldwell    Male
# 6       7  efeb05c7Cc94EA3     Ernest   Hoffman    Male
# 7       8  fb1BF3FED57E9d7      Doris  Andersen    Male
# 8       9  421fAB9a3b98F30     Cheryl      Mays    Male
# 9      10  4A42Fe10dB717CB      Harry  Mitchell    Male
# 10     11  44FAA9C3CE8DB2B      Casey     Ayala    Male
# 11     12  86cCc6417942b4B       Sara      Huff    Male
# 12     13  CDA21B6e83Cafe3      Eddie    Barnes  Female
# 13     14  1CC30c5F204332e      Ralph      Lowe  Female
# 14     15  b4bE3BfBfeBC29e  Priscilla     Davis    Male
# 15     16  bFCFDdE5491caE8      Carly    Abbott  Female
# ...

# %% [markdown]
# ### Q13

# %%
np.random.seed(12)
x = np.random.rand(100)
y = np.random.rand(100)

# Create scatter plot
plt.scatter(x, y, color='red', marker='o', label='Data Points')
plt.axhline(y=0.5, color='black', linestyle='--', label='y = 0.5')
plt.axvline(x=0.5, color='blue', linestyle=':', label='x = 0.5')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Advanced Scatter Plot of Random Values')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Q14

# %%
# Sample time-series data
np.random.seed(24) 
date_range = pd.date_range(start='2024-01-01', periods=30)
temperature = np.random.randint(20, 40, size=30)
humidity = np.random.randint(30, 90, size=30)

df_time = pd.DataFrame({'Date': date_range, 'Temperature': temperature, 'Humidity': humidity})

# Plot
fig, ax1 = plt.subplots(figsize=(10, 6))

# Temperature plot
line1, = ax1.plot(df_time['Date'], df_time['Temperature'], 'r-', label='Temperature')
ax1.set_ylabel('Temperature (°C)', color='red')

# Create second y-axis for humidity
ax2 = ax1.twinx()
line2, = ax2.plot(df_time['Date'], df_time['Humidity'], 'b--', label='Humidity')
ax2.set_ylabel('Humidity (%)', color='blue')

# Combine legends from both axes
lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left')

# Labels and title
ax1.set_xlabel('Date')
plt.title('Temperature and Humidity Over Time')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Q15 & Q16

# %%
from scipy.stats import norm

np.random.seed(45)
# Generate normal distribution data
data = np.random.normal(loc=0, scale=1, size=1000)

# Histogram
count, bins, ignored = plt.hist(data, bins=30, density=True, alpha=0.6, color='g', label='Histogram')

# PDF overlay
pdf = norm.pdf(bins, 0, 1)
plt.plot(bins, pdf, 'k', linewidth=2, label='Normal PDF')

# Labels and title
plt.xlabel('Value')
plt.ylabel('Frequency/Probability')
plt.title('Histogram with PDF Overlay')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Q17

# %%
np.random.seed(23)
x = np.random.uniform(-1, 1, 200)
y = np.random.uniform(-1, 1, 200)

# Determine quadrant
def quadrant(x, y):
    if x > 0 and y > 0:
        return 'Q1'
    elif x < 0 and y > 0:
        return 'Q2'
    elif x < 0 and y < 0:
        return 'Q3'
    else:
        return 'Q4'

df_quadrant = pd.DataFrame({'x': x, 'y': y})
df_quadrant['Quadrant'] = [quadrant(a, b) for a, b in zip(x, y)]

# Scatter plot
plt.figure(figsize=(8,6))
sns.scatterplot(data=df_quadrant, x='x', y='y', hue='Quadrant', palette='Set1')
plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')
plt.title('Quadrant-wise Scatter Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Q18

# %%
from bokeh.plotting import figure, show, output_notebook

output_notebook()

x = np.linspace(0, 4 * np.pi, 100)
y = np.sin(x)

p = figure(title='Sine Wave Function', x_axis_label='X', y_axis_label='sin(X)', width=700, height=400)
p.line(x, y, line_width=2, color="navy")

p.grid.visible = True
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="aa918a4b-4f3b-4a1d-aa18-f5d4b8781cbe">Loading BokehJS ...</span>
#     </div>
#   <div id="e7fc4cdb-3286-42eb-982b-e2be489a6861" data-root-id="p1099" style="display: contents;"></div>

# %% [markdown]
# ### Q19

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import ColumnDataSource, HoverTool

output_notebook()
np.random.seed(46)

# Generate data
categories = [f'Cat {i}' for i in range(1, 6)]
values = np.random.randint(10, 100, size=5)

source = ColumnDataSource(data=dict(categories=categories, values=values, color=["#%06x" % np.random.randint(0, 0xFFFFFF) for _ in range(5)]))

# Plot
p = figure(x_range=categories, title="Random Categorical Bar Chart", x_axis_label='Category', y_axis_label='Value', width=700, height=400)
p.vbar(x='categories', top='values', width=0.5, color='color', source=source)

# Hover tool
hover = HoverTool()
hover.tooltips = [("Category", "@categories"), ("Value", "@values")]
p.add_tools(hover)

show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e0024179-13ae-4869-88aa-ce30217f17f5">Loading BokehJS ...</span>
#     </div>
#   <div id="f5ab1716-a418-4616-8a85-80732225c314" data-root-id="p1148" style="display: contents;"></div>

# %% [markdown]
# ### Q20

# %%
import plotly.graph_objs as go

np.random.seed(45)
x = np.linspace(0, 10, 100)
y = np.random.rand(100)

fig = go.Figure()
fig.add_trace(go.Scatter(x=x, y=y, mode='lines', name='Random Line'))

fig.update_layout(
    title='Simple Line Plot',
    xaxis_title='X-axis',
    yaxis_title='Y-axis'
)

fig.show()

# %% [markdown]
# ### Q21

# %%
import plotly.express as px
np.random.seed(90)

labels = ['A', 'B', 'C', 'D', 'E']
values = np.random.randint(10, 100, size=5)

fig = px.pie(values=values, names=labels, title='Interactive Pie Chart', hole=0.3)
fig.update_traces(textinfo='percent+label')

fig.show()
